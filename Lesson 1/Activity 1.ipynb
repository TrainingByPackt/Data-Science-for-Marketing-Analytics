# %%
import pandas as pd

# %%
user_info = pd.read_json("user_info.json")

# %%
sales = pd.read_excel("sales.xlsx")

# %%
user_info
# Out:
#                         _id  \
# 0  5c0a28d7a647437fd3d3a6aa
# 1  5c0a28d780f6278b11586ab1
# 2  5c0a28d722e2e29d9bce2b64
# 3  5c0a28d76b5e8859a754cb4f
# 4  5c0a28d7ebb99c08e2288c76
# 5  5c0a28d749ce43912931715e
#
#                                                about  \
# 0  Nostrud consectetur elit occaecat dolore incid...
# 1  Sunt id ipsum velit voluptate. Ullamco non non...
# 2  Laborum ad excepteur amet sunt aliqua veniam c...
# 3  Eu amet aliqua magna ipsum quis et ut reprehen...
# 4  Sunt amet exercitation aliqua cillum commodo o...
# 5  Occaecat dolor minim et nisi cupidatat ipsum. ...
#
#                                              address  age    balance  \
# 0        698 Kansas Place, Bethpage, Louisiana, 7695   20  $3,806.93
# 1      309 Kingsway Place, Kilbourne, New York, 3771   22  $3,330.01
# 2            347 Seeley Street, Witmer, Kansas, 9369   40  $1,619.46
# 3          178 Stewart Street, Ferney, Wyoming, 9118   29  $3,334.12
# ...

# %%
sales
# Out:
#        Year  Product       line Product.1  type  Product.2  Order  method  \
# 0      2004  Camping  Equipment   Cooking  Gear  TrailChef  Water     Bag
# 1      2004  Camping  Equipment   Cooking  Gear  TrailChef  Water     Bag
# 2      2004  Camping  Equipment   Cooking  Gear  TrailChef  Water     Bag
# 3      2004  Camping  Equipment   Cooking  Gear  TrailChef  Water     Bag
# 4      2004  Camping  Equipment   Cooking  Gear  TrailChef  Water     Bag
# 5      2004  Camping  Equipment   Cooking  Gear  TrailChef  Water     Bag
# 6      2004  Camping  Equipment   Cooking  Gear  TrailChef  Water     Bag
# 7      2004  Camping  Equipment   Cooking  Gear  TrailChef  Water     Bag
# 8      2004  Camping  Equipment   Cooking  Gear  TrailChef  Water     Bag
# 9      2004  Camping  Equipment   Cooking  Gear  TrailChef  Water     Bag
# 10     2004  Camping  Equipment   Cooking  Gear  TrailChef  Water     Bag
# 11     2004  Camping  Equipment   Cooking  Gear  TrailChef  Water     Bag
# ...

# %%
sales.columns
# Out:
# Index(['Year', 'Product', 'line', 'Product.1', 'type', 'Product.2', 'Order',
#        'method', 'type.1', 'Retailer', 'country', 'Revenue', 'Planned',
#        'revenue', 'Product.3', 'cost', 'Quantity', 'Unit', 'cost.1', 'Unit.1',
#        'price', 'Gross', 'profit', 'Unit.2', 'sale', 'price.1'],
#       dtype='object')

# %%
sales_columns  = ['Year', 'Product line', 'Product type', 'Product', 'Order', 'method type', 'Retailer country', 'Revenue', 'Planned revenue', 'Product cost', 'Quantity', 'Unit cost', 'Unit price','Gross Profit', 'Unit sale price']

# %%
sales[10:3:-1]
# Out:
#     Year  Product       line Product.1  type  Product.2  Order method  \
# 10  2004  Camping  Equipment   Cooking  Gear  TrailChef  Water    Bag
# 9   2004  Camping  Equipment   Cooking  Gear  TrailChef  Water    Bag
# 8   2004  Camping  Equipment   Cooking  Gear  TrailChef  Water    Bag
# 7   2004  Camping  Equipment   Cooking  Gear  TrailChef  Water    Bag
# 6   2004  Camping  Equipment   Cooking  Gear  TrailChef  Water    Bag
# 5   2004  Camping  Equipment   Cooking  Gear  TrailChef  Water    Bag
# 4   2004  Camping  Equipment   Cooking  Gear  TrailChef  Water    Bag
#
#        type.1     Retailer   ...     Quantity   Unit cost.1 Unit.1 price  \
# 10  Telephone       Sweden   ...      8699.22  3.950    NaN    NaN   NaN
# 9   Telephone  Netherlands   ...     37789.55  5.585    NaN    NaN   NaN
# 8   Telephone    Australia   ...          NaN    NaN    NaN    NaN   NaN
# 7   Telephone    Singapore   ...     14569.38  3.950    NaN    NaN   NaN
# ...

# %%
sales['Year'].hist()

# %%
sales[['Product', 'Year', 'price']].unstack().unstack()
# Out:
#            0        1        2        3        4        5        6      \
# Product  Camping  Camping  Camping  Camping  Camping  Camping  Camping
# Year        2004     2004     2004     2004     2004     2004     2004
# price        NaN      NaN      NaN      NaN      NaN      NaN      NaN
#
#            7        8        9       ...       65525    65526    65527  \
# Product  Camping  Camping  Camping   ...     Camping  Camping  Camping
# Year        2004     2004     2004   ...        2007     2007     2007
# price        NaN      NaN      NaN   ...         NaN      NaN      NaN
#
#            65528    65529    65530    65531    65532    65533    65534
# Product  Camping  Camping  Camping  Camping  Camping  Camping  Camping
# Year        2007     2007     2007     2007     2007     2007     2007
# price        NaN      NaN      NaN      NaN      NaN      NaN      NaN
#
# [3 rows x 65535 columns]
